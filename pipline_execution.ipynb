# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached papermill-2.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached ansicolors-1.1.8-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 142.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 98.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 100.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 104.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 74.3 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 34.8 MB/s eta 0:00:00
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ...

# %%
from IPython.display import Image, display

# Assuming 'output_image_path' is the path to your saved image
output_image_path = 'output/xai_outputs/gradcam_output.png'

display(Image(filename=output_image_path))

# %%
# %run pipeline.py
# Out:
# Starting pipeline...
# Creating watermarked images...
# XAI evaluation...
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Grad-CAM output available at: output/xai_outputs/gradcam_output.png
# Metrics evaluation...
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Metric output available at: output/metrics_outputs/metrics.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/project/watermarked-image-classification/pipeline.py:205
#     202 # Optionally, display the image in an interactive session
#     203 # This requires an environment like Jupyter Notebook or JupyterLab
#     204 from IPython.display import Image, display
# --> 205 display(Image(filename=metrics_output_path))
#     208 print("Pipeline execution completed!")
#
# ...
